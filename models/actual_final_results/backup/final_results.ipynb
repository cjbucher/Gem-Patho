# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
base_dirs = {
    "genetics_and_image": "/home/chb3333/yulab/chb3333/gem-patho/models/actual_final_results/genetics_and_image",
    "only_genetics": "/home/chb3333/yulab/chb3333/gem-patho/models/actual_final_results/only_genetics",
    "only_image": "/home/chb3333/yulab/chb3333/gem-patho/models/actual_final_results/only_image"
}


sub_folders = {
    "all_batch": ["cancertypebatching_exp_0_phase2_10", "cancertypebatching_exp_1_phase2_0"],
    "ct_batch": ["cancertypebatching_exp_0_warmup_0", "cancertypebatching_exp_1_warmup_10"]
}

csv_files = ["global_test_cindices.csv", "global_test_risk_scores.csv"]


all_csv_data = {}

for mode, base_dir in base_dirs.items():
    all_csv_data[mode] = {}
    for batch_type, exp_dirs in sub_folders.items():
        all_csv_data[mode][batch_type] = {}
        for exp_dir in exp_dirs:
            exp_path = os.path.join(base_dir, batch_type, exp_dir)
            all_csv_data[mode][batch_type][exp_dir] = {}
            for csv_file in csv_files:
                file_path = os.path.join(exp_path, csv_file)
                try:
                    all_csv_data[mode][batch_type][exp_dir][csv_file] = pd.read_csv(file_path)
                except FileNotFoundError:
                    print(f"Missing: {file_path}")
                    all_csv_data[mode][batch_type][exp_dir][csv_file] = None

# %%
base_dir = "/home/chb3333/yulab/chb3333/gem-patho/models/actual_final_results/genetics_and_image"
batch_type = "all_batch"
exp_dir = "cancertypebatching_exp_0_phase2_10"
csv_file = "global_test_cindices.csv"

file_path = os.path.join(base_dir, batch_type, exp_dir, csv_file)

# Load the CSV
cindex_df = pd.read_csv(file_path)
print(cindex_df)
# Out:
#     cancer_type   c_index
# 0             8  0.501033
# 1             2  0.532815
# 2            10  0.486309
# 3            12  0.585014
# 4            11  0.554278
# 5            17  0.634139
# 6            15  0.508911
# 7            13  0.635819
# 8            20  0.547747
# 9            19  0.516460
# 10            6  0.571491
# 11            7  0.567961
# 12            3  0.504971
# 13            4  0.621094
# 14            1  0.581763
# 15            0  0.707595
# 16           21  0.596875
# 17           18  0.584267
# 18           35  0.501114
# 19           36  0.512273
# 20           14  0.555773
# 21           26  0.550651
# 22           28  0.621091
# 23           27  0.497244
# 24           23  0.539118
# 25           33  0.636175
# 26           25  0.505593
# 27           32  0.523862
# 28           30  0.551342
# 29           31  0.658768
# 30           24  0.582915
# 31           29  0.570370
# 32           34  0.609166

# %%
base_dir = "/home/chb3333/yulab/chb3333/gem-patho/models/actual_final_results/genetics_and_image"
batch_type = "all_batch"
exp_dir = "cancertypebatching_exp_0_phase2_10"
csv_file = "global_test_cindices.csv"
file_path = os.path.join(base_dir, batch_type, exp_dir, csv_file)

df = pd.read_csv(file_path)

# Group by cancer_type (not necessary here unless duplicates, but okay for consistency)
agg_df = df.groupby("cancer_type")["c_index"].agg(["mean", "std"]).reset_index()

# Plot
plt.figure(figsize=(10, 6))
sns.barplot(data=agg_df, x="cancer_type", y="mean", yerr=agg_df["std"])
plt.xlabel("Cancer Type")
plt.ylabel("Mean C-Index")
plt.title("Cancer-Type Specific C-Index (Mean ± Std)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 14
#      12 # Plot
#      13 plt.figure(figsize=(10, 6))
# ---> 14 sns.barplot(data=agg_df, x="cancer_type", y="mean", yerr=agg_df["std"])
#      15 plt.xlabel("Cancer Type")
#      16 plt.ylabel("Mean C-Index")
#
# File ~/.conda/envs/nns/lib/python3.12/site-packages/seaborn/categorical.py:2371, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
#    2369 saturation = saturation if fill else 1
#    2370 p.map_hue(palette=palette, order=hue_order, norm=hue_norm, saturation=saturation)
# -> 2371 color = _default_color(ax.bar, hue, color, kwargs, saturation=saturation)
#    2373 agg_cls = WeightedAggregator if "weight" in p.plot_data else EstimateAggregator
#    2374 aggregator = agg_cls(estimator, errorbar, n_boot=n_boot, seed=seed)
#
# File ~/.conda/envs/nns/lib/python3.12/site-packages/seaborn/utils.py:127, in _default_color(method, hue, color, kws, saturation)
#     122     scout.remove()
#     124 elif method.__name__ == "bar":
#     125
#     126     # bar() needs masked, not empty data, to generate a patch
# --> 127     scout, = method([np.nan], [np.nan], **kws)
#     128     color = to_rgb(scout.get_facecolor())
#     129     scout.remove()
#
# File ~/.conda/envs/nns/lib/python3.12/site-packages/matplotlib/__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# -> 1521         return func(
#    1522             ax,
#    1523             *map(cbook.sanitize_sequence, args),
#    1524             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1526     bound = new_sig.bind(ax, *args, **kwargs)
#    1527     auto_label = (bound.arguments.get(label_namer)
#    1528                   or bound.kwargs.get(label_namer))
#
# File ~/.conda/envs/nns/lib/python3.12/site-packages/matplotlib/axes/_axes.py:2665, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2661         ey = [b + 0.5 * h for b, h in zip(bottom, height)]
#    2663     error_kw.setdefault("label", '_nolegend_')
# -> 2665     errorbar = self.errorbar(ex, ey, yerr=yerr, xerr=xerr, fmt='none',
#    2666                              **error_kw)
#    2667 else:
#    2668     errorbar = None
#
# File ~/.conda/envs/nns/lib/python3.12/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File ~/.conda/envs/nns/lib/python3.12/site-packages/matplotlib/__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# -> 1521         return func(
#    1522             ax,
#    1523             *map(cbook.sanitize_sequence, args),
#    1524             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1526     bound = new_sig.bind(ax, *args, **kwargs)
#    1527     auto_label = (bound.arguments.get(label_namer)
#    1528                   or bound.kwargs.get(label_namer))
#
# File ~/.conda/envs/nns/lib/python3.12/site-packages/matplotlib/axes/_axes.py:3785, in Axes.errorbar(self, x, y, yerr, xerr, fmt, ecolor, elinewidth, capsize, barsabove, lolims, uplims, xlolims, xuplims, errorevery, capthick, **kwargs)
#    3783     np.broadcast_to(err, (2, len(dep)))
#    3784 except ValueError:
# -> 3785     raise ValueError(
#    3786         f"'{dep_axis}err' (shape: {np.shape(err)}) must be a "
#    3787         f"scalar or a 1D or (2, n) array-like whose shape matches "
#    3788         f"'{dep_axis}' (shape: {np.shape(dep)})") from None
#    3789 if err.dtype is np.dtype(object) and np.any(err == None):  # noqa: E711
#    3790     raise ValueError(
#    3791         f"'{dep_axis}err' must not contain None. "
#    3792         "Use NaN if you want to skip a value.")
#
# ValueError: 'yerr' (shape: (33,)) must be a scalar or a 1D or (2, n) array-like whose shape matches 'y' (shape: (1,))

# %% [markdown]
# Kaplan Meier Plots

# %%
base_dir = "/home/chb3333/yulab/chb3333/gem-patho/models/actual_final_results/genetics_and_image"
batch_type = "all_batch"
exp_dir = "cancertypebatching_exp_0_phase2_10"
csv_file = "global_test_risk_scores.csv"

file_path = os.path.join(base_dir, batch_type, exp_dir, csv_file)

# Load the CSV
risk_df = pd.read_csv(file_path)
print(risk_df)
# Out:
#            Case ID  OS.time   OS       risk  normalized_risk  cancer_type  \
# 0     TCGA-L5-A43C     96.0  0.0   7.782428        -0.003303            8
# 1     TCGA-L5-A4OO    101.0  0.0   7.992639         0.198492            8
# 2     TCGA-R6-A6L4    496.0  1.0   6.285508        -1.440291            8
# 3     TCGA-E2-A154    591.0  0.0   7.760184        -0.024656            2
# 4     TCGA-EW-A1OV    789.0  0.0   7.998481         0.204101            2
# ...            ...      ...  ...        ...              ...          ...
# 9445  TCGA-EY-A549    605.0  0.0  20.607252         0.258104           34
# 9446  TCGA-AP-A1DH   2180.0  0.0  22.334840         1.058286           34
# 9447  TCGA-AP-A052    669.0  1.0  23.275385         1.493926           34
# 9448  TCGA-A5-A0GV   1643.0  0.0  20.695097         0.298792           34
# 9449  TCGA-EY-A3L3    832.0  0.0  20.373226         0.149708           34
#
#       fold
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
# ...    ...
# 9445    10
# 9446    10
# 9447    10
# 9448    10
# 9449    10
#
# [9450 rows x 7 columns]

# %%
import pandas as pd
from lifelines import KaplanMeierFitter
import matplotlib.pyplot as plt

# %%
risk8_df = risk_df[risk_df["cancer_type"] == 0]
risk8_df['OS.time'] = risk8_df['OS.time'] / 365.25
# Out:
# /tmp/ipykernel_53405/2667496660.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   risk8_df['OS.time'] = risk8_df['OS.time'] / 365.25

# %%
median_risk = risk8_df['normalized_risk'].median()
high_risk = risk8_df[risk8_df['normalized_risk'] >= median_risk]
low_risk = risk8_df[risk8_df['normalized_risk'] < median_risk]

# %%
kmf_high = KaplanMeierFitter()
kmf_low = KaplanMeierFitter()

# %%
kmf_low.fit(low_risk['OS.time'], event_observed=low_risk['OS'], label="Low Risk")
kmf_high.fit(high_risk['OS.time'], event_observed=high_risk['OS'], label="High Risk")
# Out:
# <lifelines.KaplanMeierFitter:"High Risk", fitted with 41 total observations, 23 right-censored observations>

# %%
ax = kmf_high.plot()
kmf_low.plot(ax=ax)
plt.title('Kaplan-Meier Survival Curve by Risk Group (Cancer Type: LAML)')
plt.xlabel('Time (years)')
plt.ylabel('Survival Probability')
plt.grid(True)

plt.show()

# %%
risk8_df = risk_df[risk_df["cancer_type"] == 8]
risk8_df['OS.time'] = risk8_df['OS.time'] / 365.25
# Out:
# /tmp/ipykernel_53405/2667496660.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   risk8_df['OS.time'] = risk8_df['OS.time'] / 365.25

# %%
kmf.plot()

# Customize the plot (optional)
plt.title('Kaplan-Meier Survival Curve')
plt.xlabel('Time')
plt.ylabel('Survival Probability')
plt.grid(True)

# Show the plot
plt.show()
